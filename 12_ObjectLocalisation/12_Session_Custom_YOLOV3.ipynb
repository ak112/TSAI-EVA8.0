# %% [markdown]
# <a href="https://colab.research.google.com/drive/1dcOOEuOxZmoQ0L83KbqZATxL8ZEDTkqs" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>

# %%
import time
import glob
import torch
import os
from IPython.display import Image, clear_output

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/YOLOV3
# Out:
# cfg	   models.py	results.txt	 test.py	   utils
# data	   output	runs		 train_batch0.png  weights
# detect.py  results.png	test_batch0.png  train.py

# %%
# !ln -s "/content/drive/MyDrive/YOLOV3/" "/content/YOLOV3"

# %%
# !python3 train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300
# Out:
# Namespace(epochs=300, batch_size=10, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=False, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', total_memory=40513MB)
#
# 2023-03-28 18:10:02.949857: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python detect.py --cfg cfg/yolov3-custom.cfg --conf-thres 0.3 --output output
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='data/customdata/images', output='output', img_size=512, conf_thres=0.3, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', total_memory=40513MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/79 data/customdata/images/bean_10_10_11zon.jpg: 320x512 1 MrBeans, Done. (0.030s)
# image 2/79 data/customdata/images/bean_11_11_11zon.jpg: 320x512 1 MrBeans, Done. (0.017s)
# ...

# %%
# !rm -r /content/runs

# %%
Image(filename='/content/output/bean_2_2_11zon.jpg', width=400)

# %%
Image(filename='/content/output/oggy_12_12_11zon.jpg', width=400)

# %%
Image(filename='/content/output/cyber_25_25_11zon.jpg', width=400)

# %%
Image(filename='/content/output/roach_13_13_11zon.jpg', width=400)

# %%
# !ffmpeg -i Cybertruck.mp4 -vf fps=30 out%d.png #Extracting the frames
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
# !python detect.py --cfg cfg/yolov3-custom.cfg --conf-thres 0.3 --output out_video #Running saved model on extracted frames
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='data/customdata/images', output='out_video', img_size=512, conf_thres=0.3, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', total_memory=40513MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/1037 data/customdata/images/out1.png: 320x512 Done. (0.023s)
# image 2/1037 data/customdata/images/out10.png: 320x512 Done. (0.018s)
# ...

# %%
# !ffmpeg -framerate 30 -pattern_type glob -i '*.png' \-c:v libx264 -pix_fmt yuv420p /content/out_5.mp4 #Converting the frames to get the output video
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...
